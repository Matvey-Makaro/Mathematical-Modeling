# %%
# Model 1

# Классификация: 
# 1-ограничена (конечное число токенов для каждой позиции)
# безопасна (так как 1-ограничена)
# 1-консервативна (количество маркеров в процессе симуляции не меняется)
# Консервативна
# неживая (тупик есть)
# не устойчивая

# Маркировка (0, 1, 0, 1, 0) - достижима 
# Маркировка (0, 0, 0, 1, 1) - не достижима

# Параллельное срабатывание возможно(t1 и t2)

# Классы Петри:
# Не автоматная сеть петри ( из-за t3)
# Не маркированный граф (из-за p4)
# Cеть свободного выбора

# %%
# Model 2


# Классификация: 
# 2-ограничена (конечное число токенов для каждой позиции, у p6 - 2)
# не безопасна(т.к. 2-ограничена)
# ограниченная 
# не 1-консервативна(общее число маркеров не остается постоянным)
# Консервативна(т.к количество маркеров не увеличив. бесконечно)
# живая(каждый переход является потенциально срабатывающим)
# устойчивая(срабатывание одного возбужения не может снять другое)

# Маркировка (0, 0, 1, 1, 0, 2) - достижима 
# Маркировка (1, 1, 0, 0, 0, 2) - не достижима

# Параллельное срабатывание возможно(t2 и t3)

# Классы Петри:
# Не автоматная сеть петри ( из-за t4)
# маркированный граф (каждая позиция имеет не более одного входа и не более одного выхода)
# не сеть свободного выбора
# бесконфликтная
